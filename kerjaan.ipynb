# %%
import numpy as np
import json  
import pandas as pd
from pandas.io.json import json_normalize

# %%
df_us = pd.read_csv('../youtube-new/USvideos.csv')
df_us
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8fc2ce5ce6ff> in <module>
# ----> 1 df_us = pd.read_csv('../youtube-new/USvideos.csv')
#       2 df_us
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
df_us['country'] = 'USA'
df_us
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
with open('../youtube-new/US_category_id.json') as df_us_category_id:
    us_category = json.load(df_us_category_id)
dataframe_us_category = json_normalize(us_category['items'])
select_feature_us_category = ['id', 'snippet.title']
df_us_category = dataframe_us_category[select_feature_us_category]
df_us_category = df_us_category.rename(columns={"id":"category_id", "snippet.title":"category_title"})

# %%
df_us_category.to_csv('us_category.csv', index=False)

# %%
df_us_category = pd.read_csv('us_category.csv')
df_us_category
# Out:
#     category_id         category_title
# 0             1       Film & Animation
# 1             2       Autos & Vehicles
# 2            10                  Music
# 3            15         Pets & Animals
# 4            17                 Sports
# 5            18           Short Movies
# 6            19        Travel & Events
# 7            20                 Gaming
# 8            21          Videoblogging
# 9            22         People & Blogs
# 10           23                 Comedy
# 11           24          Entertainment
# 12           25        News & Politics
# 13           26          Howto & Style
# 14           27              Education
# 15           28   Science & Technology
# 16           29  Nonprofits & Activism
# 17           30                 Movies
# 18           31        Anime/Animation
# 19           32       Action/Adventure
# 20           33               Classics
# 21           34                 Comedy
# 22           35            Documentary
# ...

# %%
data_us = pd.merge(df_us, df_us_category, on='category_id')
data_us
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      0mlNzVSJrT0      17.14.11
# 2      STI2fI7sKMo      17.14.11
# 3      KODzih-pYlU      17.14.11
# 4      8mhTWqWlQzU      17.14.11
# ...            ...           ...
# 40944  V6ElE2xs48c      18.02.06
# 40945  V6ElE2xs48c      18.03.06
# 40946  V6ElE2xs48c      18.04.06
# 40947  V6ElE2xs48c      18.05.06
# 40948  V6ElE2xs48c      18.06.06
#
#                                                    title       channel_title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE        CaseyNeistat
# 1                                   Me-O Cats Commercial             Nobrand
# 2      AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...  Shawn Johnson East
# 3      BLIND(folded) CAKE DECORATING CONTEST (with Mo...        Grace Helbig
# 4          Wearing Online Dollar Store Makeup For A Week      Safiya Nygaard
# ...                                                  ...                 ...
# ...

# %%
df_gb = pd.read_csv('../youtube-new/GBvideos.csv')
df_gb
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
df_gb['country'] = 'Great Britain'
df_gb
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
with open('../youtube-new/GB_category_id.json') as df_gb_category_id:
    gb_category = json.load(df_gb_category_id)
dataframe_gb_category = json_normalize(gb_category['items'])
select_feature_gb_category = ['id', 'snippet.title']
df_gb_category = dataframe_gb_category[select_feature_gb_category]
df_gb_category = df_gb_category.rename(columns={"id":"category_id", "snippet.title":"category_title"})

# %%
df_gb_category.to_csv('gb_category.csv', index=False)

# %%
df_gb_category = pd.read_csv('gb_category.csv')
df_gb_category
# Out:
#     category_id        category_title
# 0             1      Film & Animation
# 1             2      Autos & Vehicles
# 2            10                 Music
# 3            15        Pets & Animals
# 4            17                Sports
# 5            18          Short Movies
# 6            19       Travel & Events
# 7            20                Gaming
# 8            21         Videoblogging
# 9            22        People & Blogs
# 10           23                Comedy
# 11           24         Entertainment
# 12           25       News & Politics
# 13           26         Howto & Style
# 14           27             Education
# 15           28  Science & Technology
# 16           30                Movies
# 17           31       Anime/Animation
# 18           32      Action/Adventure
# 19           33              Classics
# 20           34                Comedy
# 21           35           Documentary
# 22           36                 Drama
# 23           37                Family
# ...

# %%
data_gb = pd.merge(df_gb, df_gb_category, on='category_id')
data_gb
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      MyEqfBkzESU      17.14.11
# 2      b4vTZx_AtHk      17.14.11
# 3      OWvCCu2t6Ts      17.14.11
# 4      9GqL1DSQDL0      17.14.11
# ...            ...           ...
# 38821  JtIY1Naxg0M      18.10.06
# 38822  JtIY1Naxg0M      18.11.06
# 38823  JtIY1Naxg0M      18.12.06
# 38824  JtIY1Naxg0M      18.13.06
# 38825  JtIY1Naxg0M      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1                      EXTREME GOLDEN TAN TRANSFORMATION
# 2                       How To Dry a Shirt in 30 Seconds
# 3      SO Much To Tell You | 32 Weeks Pregnant | MOTH...
# 4      GET READY WITH ME + LILY! (we're so immature bye)
# ...                                                  ...
# 38821                       Game of Zones - S5E7: NBA 1K
# 38822                       Game of Zones - S5E7: NBA 1K
# ...

# %%
df = pd.concat([data_us, data_gb])
sort_columns = ['video_id', 'channel_title', 'title', 'category_id', 'category_title', 'tags', 'description', 'views', 'likes', 'dislikes', 'thumbnail_link', 'country']
data_youtube = df[sort_columns]

# %% [markdown]
# # Start From Here

# %%
data_youtube.head()
# Out:
#       video_id       channel_title  \
# 0  2kyS6SvSYSE        CaseyNeistat
# 1  0mlNzVSJrT0             Nobrand
# 2  STI2fI7sKMo  Shawn Johnson East
# 3  KODzih-pYlU        Grace Helbig
# 4  8mhTWqWlQzU      Safiya Nygaard
#
#                                                title  category_id  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           22
# 1                               Me-O Cats Commercial           22
# 2  AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...           22
# 3  BLIND(folded) CAKE DECORATING CONTEST (with Mo...           22
# 4      Wearing Online Dollar Store Makeup For A Week           22
#
#    category_title                                               tags  \
# 0  People & Blogs                                    SHANtell martin
# 1  People & Blogs                          cute|"cats"|"thai"|"eggs"
# 2  People & Blogs  shawn johnson|"andrew east"|"shawn east"|"shaw...
# 3  People & Blogs  itsgrace|"funny"|"comedy"|"vlog"|"grace"|"helb...
# ...

# %% [markdown]
# # Data Cleaning and Pre-processing

# %% [markdown]
# Tags

# %%
data_youtube
# Out:
#           video_id       channel_title  \
# 0      2kyS6SvSYSE        CaseyNeistat
# 1      0mlNzVSJrT0             Nobrand
# 2      STI2fI7sKMo  Shawn Johnson East
# 3      KODzih-pYlU        Grace Helbig
# 4      8mhTWqWlQzU      Safiya Nygaard
# ...            ...                 ...
# 38821  JtIY1Naxg0M     Bleacher Report
# 38822  JtIY1Naxg0M     Bleacher Report
# 38823  JtIY1Naxg0M     Bleacher Report
# 38824  JtIY1Naxg0M     Bleacher Report
# 38825  JtIY1Naxg0M     Bleacher Report
#
#                                                    title  category_id  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE           22
# 1                                   Me-O Cats Commercial           22
# 2      AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...           22
# 3      BLIND(folded) CAKE DECORATING CONTEST (with Mo...           22
# 4          Wearing Online Dollar Store Makeup For A Week           22
# ...
